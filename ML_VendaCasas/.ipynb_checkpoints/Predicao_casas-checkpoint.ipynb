# %% [markdown]
# # **Resumo**
# ## Este notebook fará uma pequena analise exploratória dos dados de um dataset de venda de casas, para realizar a predição de preços de novas casas com caracteristicas semelhantes as ja vendidas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("House.csv")
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2  9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                          USS Barnett\nFPO AP 44820
# 4                         USNS Raymond\nFPO AE 09386

# %% [markdown]
# ***
# ## Traduzindo colunas

# %%
df.columns = ['media de lucro de venda', 'media idade das casas', 'media numero de salas','media numero de quartos', 'populacao da regiao', 'valor da casa', 'endereco']
df.head(2)
# Out:
#    media de lucro de venda  media idade das casas  media numero de salas  \
# 0             79545.458574               5.682861               7.009188
# 1             79248.642455               6.002900               6.730821
#
#    media numero de quartos  populacao da regiao  valor da casa  \
# 0                     4.09         23086.800503   1.059034e+06
# 1                     3.09         40173.072174   1.505891e+06
#
#                                             endereco
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...

# %% [markdown]
# # Visualizando a distribuição de preços das casas por quantidade de quartos

# %%
plt.figure(dpi=120)
sns.set_style("whitegrid")
sns.set_palette("Set1")
sns.scatterplot(data=df, x="media numero de quartos", y="valor da casa")
plt.show()

# %% [markdown]
# #### OBS: Não há grande variação de preço por numero de quartos, mas da pra perceber que casas que tenha em media 2 quartos são um pouco mais baratas em seu **valor máximo**
# ***

# %% [markdown]
# # Visualizando a distribuição de preços das casas por quantidade de salas

# %%
plt.figure(dpi=120)
plt.title("Valor das casas por sala")
sns.scatterplot(data=df,x="media numero de salas", y="valor da casa")
plt.show()

# %% [markdown]
# ### OBS: obviamente como esperado, quanto maior a quantidade de salas, maior o preço da casa, em alguns poucos casos, casas com numero menor de salas sao mais caras
#
# ### OBS 2: Também é possivel notar que a grande maioria das casas possuem entre 6 a 8 salas
# ***

# %% [markdown]
# # Visualizando um gráfico das casas, onde mostra a distribuição de salas por quantidade de quartos

# %%
plt.figure(dpi=120)
sns.scatterplot(data=df,x="media numero de quartos", y="media numero de salas")
plt.show()

# %% [markdown]
# #### OBS: Podemos ver que todas as casas com 5 quartos ou mais, possuem **pelo menos** 7 salas
#
# #### OBS 2: Também observamos que casas com 2 quartos, possuem **no maximo** 7 salas
# ***

# %% [markdown]
# ## Visualizando correlação entre as colunas

# %%
plt.figure(dpi=100)
sns.heatmap(df.corr(),annot=True, cmap="OrRd")
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ## Visualizando distribuição de preços da casa por tamanho da população da região

# %%
plt.figure(dpi=120)
sns.scatterplot(data=df, x='valor da casa',y='populacao da regiao')
plt.show()

# %% [markdown]
# #### OBS: Quanto maior a população, maior o preço da casa
# ***

# %% [markdown]
# ## Visualizando como os dados se relacionam para definir qual modelo preditivo será implementado

# %%
sns.pairplot(data=df,x_vars=["media de lucro de venda", "media idade das casas","media numero de salas","populacao da regiao","valor da casa"],y_vars="valor da casa")
plt.show()

# %% [markdown]
# ###### OBS: podemos observar que há um certo grau explicativo linear sobre o preço suficiente para optarmos pelo modelo Linear Regression
# ***

# %% [markdown]
# # **Preparando dados para inicio do modelo**
# ##### Tirando a coluna endereco por ser uma coluna inviável para realizar o treinameneto, atribuindo ao X todas as colunas exceto o valor da casa, e ao y apenas o valor da casa

# %%
df.drop(columns=["endereco"], axis=1, inplace=True)

# %%
X = df.iloc[:,:-1]
y = df["valor da casa"]

# %% [markdown]
# ### Importação de libs essenciais para o funcionamento do modelo

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %% [markdown]
# ### Efetuando treino

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.4, random_state=101)
lm = LinearRegression()
lm.fit(Xtrain, ytrain)
# Out:
# LinearRegression()

# %% [markdown]
# ### Avaliando a acurácia do modelo

# %%
pred = lm.predict(Xtest)

# %%
plt.figure(dpi=120)
plt.title("Avaliando precisão do modelo")
plt.xlabel("Valores do eixo X")
plt.ylabel("Valores do eixo Y")
sns.scatterplot(ytest, pred)
plt.show()

# %% [markdown]
# #### OBS: podemos observar que  os valores do eixo X(valores previstos) e do eixo Y(valores de teste) estão próximos
# ***

# %% [markdown]
# ## Visualizando a margem de erros

# %%
sns.displot(ytest - pred)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-37da9a53e1df> in <module>
# ----> 1 sns.displot(ytest - pred)
#       2 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'displot'

# %% [markdown]
# #### OBS: Observamos que a margem de erro fica próxima de zero
# ***

# %% [markdown]
# # **Resumo das métricas de previsão deste modelo**
# ### Averiguando porcentagem Acurácia do modelo

# %%
acuracia = lm.score(Xtest, ytest) * 100
print(f"{acuracia:.0f}% de chance de acerto")

# %% [markdown]
# #### OBS: o movelo conseguiu uma acurácia de **92%**, o que é bom
# ***
